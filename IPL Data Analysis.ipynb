# %% [markdown]
# <html>
#     <body>
# <br>
# <Table>
#             <tr>
#  <td>
# <font face = "calibri" size="6" color="black"><center><b>Exploratory Data Analysis For IPL</b></center></td> </tr>
# </Table>
#  <P>
#    <Table align="right">
#                <tr> <td align="left">
#         <font face = "calibri" size="3.5" color="black"><b>Submitted By - </td></tr>
#         <tr > <td align="left">
#         <font face = "calibri" size="3.5" color="green" ><i>Siddhartha Jain </i></td></tr>
#         <tr> <td align="left"><font face = "calibri" color="black" size="2.5" > Consultant|Data Engineer|Analyst|Data Scientist </td></tr>
#    </Table>
#  </p>
#         </body>
#   </html>

# %% [markdown]
# ## Table of Contents
#
# 1. [Problem Statement](#section1)<br>
# 2. [Data Loading and Description](#section2)
# 3. [Data Profiling](#section3)
#     - 3.1 [Understanding the Dataset](#section301)<br/>
#     - 3.2 [Pre Profiling](#section302)<br/>
#     - 3.3 [Preprocessing](#section303)<br/>
#     - 3.4 [Post Profiling](#section304)<br/>
# 4. [Questions](#section4)
#     - 4.1 [Most and Least matches played](#section410)
#         - 4.1.1 [In which season highest and lowest number of matches played?](#section411)<br/>
#         - 4.1.2 [Which team played highest and lowest number of matches?](#section412)<br/>
#         - 4.1.3 [Which team played highest and lowest number of matches in each season?](#section413)<br/>
#         - 4.1.4 [What was the result of most number of the matches?](#section414)<br/>
#         - 4.1.5 [What was the result of most number of the matches in each season?](#section415)<br/>
#     - 4.2 [Does venue favours any team or impact match result by batting first or fielding first?](#section420)
#         - 4.2.1 [Which venue hosted higest number of matches?](#section421)<br/>
#         - 4.2.2 [Win percentage at each venue by first batting or bowling? ](#section422)<br/>
#         - 4.2.3 [Win percentage of team venue wise? ](#section423)<br/>
#         - 4.2.4 [Win percentage of team venue,batting and bowling wise? ](#section424)<br/>
#     - 4.3 [Which one is the most consistent team?](#section430) <br/>
#         - 4.3.1 [What percentage of matches won by each team ?](#section431)<br/>
#         - 4.3.2 [What is the win consistancy of the top teams across all the season?](#section432)<br/>
#         - 4.3.3 [What is the team performance (win) season over season?](#section433)<br/>
#     - 4.4 [Does toss really matter ?](#section440)<br/>
#     - 4.5 [What happened in the final matches of the seasons?](#section450)
#         - 4.5.1 [Which two teams reached to the finals of each season,who is the winner and Man of the match?](#section451)<br/>
#         - 4.5.2 [Which team reached to the finals maximum number of times?](#section452)<br/>
#         - 4.5.3 [Which team won the IPL final Maximum number of times ?](#section453)<br/>
#         - 4.5.4 [What are the chances for a final's qualifier to win the finals](#section454) <br/>
#     - 4.6 [Other](#section460)
#          - 4.6.1 [What percentage of matches used DL Method ?](#section461)<br/>
# 5. [Conclusions](#section5)<br/>

# %% [markdown]
# <a id=section1></a>

# %% [markdown]
# ### 1. Problem Statement

# %% [markdown]
# __Cricket__ one of the most loved and favorite sports entertainment specially in India. Here I present data analysis for IPL (Indian Premier League) matches from the beginning till year 2018.
#
# Let’s mine the data of IPL and derive some important primitives from it like
#
#      - Most and Least matches played?
#      - Does venue favours any team or impact match result by batting first or fielding first?
#      - Which one is the most consistent team?
#      - Does toss really matter?
#      - What happened to the finals?
#
# We will try to find out answers of all those questions in our analysis.
#
# In order to finding out solution for this problem we explore the basic use of __Pandas__ and will cover the basic commands of __Exploratory Data Analysis(EDA)__ which includes __cleaning__, __munging__, __combining__, __reshaping__, __slicing__, __dicing__, and __transforming data__ for analysis purpose.

# %% [markdown]
# <a id=section2></a>

# %% [markdown]
# ### 2. Data Loading and Description
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id=section201></a>

# %% [markdown]
# - The dataset consists of the information about IPL (Indian Premier League) for different seasons. Various variables present in the dataset includes data of season, city, date, team1, team2, toss_winner, toss_decision, result etc.
# - The dataset comprises of __696 observations of 18 columns__. Below is a table showing names of all the columns and their description.

# %% [markdown]
# | Column Name     | Description                                          |
# | -------------   |:-------------                                       :|
# | id			  | It's acting like a primary key for the data          |
# | season 		  | Contains IPL season i.e. Year                        |
# | city 			  | City where the Cricket match played                  |
# | date 			  | Scheduled Date for the match 	                     |
# | team1 		  | Name of the paritcipating team 1                     |
# | team2 		  | Name of the paritcipating team 2	                 |
# | toss_winner	  | Team name who won the toss                           |
# | toss_decision	  | Winning team decision either for fielding or batting |
# | result		  | Result of the match (No result,normal,tie)           |
# | dl_applied      | DL applied or not 0 or 1                             |
# | winner 		  | Team who is winner of the match                      |
# | win_by_runs	  | Win by runs by a team                                |
# | win_by_wickets  | Win by wickets by a team                             |
# | player_of_match | Player of the match                                  |
# | venue 		  | Stadium name where match was played                  |
# | umpire1		  | Umpire 1 name                                        |
# | umpire2		  | Umpire 2 name                                        |
# | umpire3		  | Umpire 3 name                                        |

# %% [markdown]
# #### Some Background Information
#
# The __Indian Premier League (IPL)__ is a professional __Twenty20 cricket league__ in __India__ contested during March or April and May of every year by __eight teams__ representing __eight different cities in India__.The league was founded by the __Board of Control for Cricket in India (BCCI)__ in __2008__. IPL has an exclusive window in ICC Future Tours Programme.
# The IPL is the most-attended cricket league in the world and in 2014 ranked sixth by average attendance among all sports leagues.In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube. The brand value of IPL in 2018 was __US$6.3 billion__, according to Duff & Phelps. According to __BCCI__, the __2015 IPL season contributed ₹11.5 billion__ to the GDP of the Indian economy.
# There have been __twelve seasons__ of the IPL tournament. The current IPL title holders are the __Mumbai Indians__, who won the __2019__ season but we have data till season 2018.

# %% [markdown]
# #### Importing packages

# %%
import plotly.express as px
import plotly.graph_objects as go
from matplotlib.ticker import FuncFormatter
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas as pd                                                # For data manipulation and analysis
import pandas_profiling
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
sns.set()

from subprocess import check_output

# %% [markdown]
# Importing the Dataset

# %%
ipl_data = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/matches.csv")     # Importing training dataset using pd.read_csv

# %% [markdown]
# <a id=section3></a>

# %% [markdown]
# ## 3. Data Profiling

# %% [markdown]
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# <a id=section301></a>

# %% [markdown]
# ### 3.1 Understanding the Dataset

# %% [markdown]
# To gain insights from data we must look into each aspect of it very carefully. We will start with observing few rows and columns of data both from the starting and from the end

# %%
ipl_data.shape                                                    # This will print the number of rows and comlumns of the Data Frame
# Out:
# (696, 18)

# %% [markdown]
# ipl data set has __696 rows__ and __18 columns.__

# %%
ipl_data.columns                                            # This will print the names of all columns.
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl_data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_data.tail()
# Out:
#        id  season     city      date                  team1  \
# 691  7949    2018     Pune  20/05/18        Kings XI Punjab
# 692  7950    2018   Mumbai  22/05/18    Sunrisers Hyderabad
# 693  7951    2018  Kolkata  23/05/18  Kolkata Knight Riders
# 694  7952    2018  Kolkata  25/05/18    Sunrisers Hyderabad
# 695  7953    2018   Mumbai  27/05/18    Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# 691    Chennai Super Kings    Chennai Super Kings         field  normal
# 692    Chennai Super Kings    Chennai Super Kings         field  normal
# 693       Rajasthan Royals       Rajasthan Royals         field  normal
# 694  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 695    Chennai Super Kings    Chennai Super Kings         field  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 691           0    Chennai Super Kings            0               5
# ...

# %% [markdown]
# <a id=section301></a>

# %% [markdown]
#    #### List of Teams:

# %%
teams = set(ipl_data.team1.unique())
print(sorted(teams)) # looks like a spell mistake for 'Rising Pune Supergiant', 'Rising Pune Supergiants'
# Out:
# ['Chennai Super Kings', 'Deccan Chargers', 'Delhi Daredevils', 'Gujarat Lions', 'Kings XI Punjab', 'Kochi Tuskers Kerala', 'Kolkata Knight Riders', 'Mumbai Indians', 'Pune Warriors', 'Rajasthan Royals', 'Rising Pune Supergiant', 'Rising Pune Supergiants', 'Royal Challengers Bangalore', 'Sunrisers Hyderabad']

# %%
teams = set(ipl_data.team2.unique())
print(sorted(teams))
# Out:
# ['Chennai Super Kings', 'Deccan Chargers', 'Delhi Daredevils', 'Gujarat Lions', 'Kings XI Punjab', 'Kochi Tuskers Kerala', 'Kolkata Knight Riders', 'Mumbai Indians', 'Pune Warriors', 'Rajasthan Royals', 'Rising Pune Supergiant', 'Rising Pune Supergiants', 'Royal Challengers Bangalore', 'Sunrisers Hyderabad']

# %%
ipl_data.info()                                                   # This will give Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               689 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             693 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    693 non-null object
# venue              696 non-null object
# umpire1            695 non-null object
# umpire2            695 non-null object
# umpire3            60 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %%
ipl_data.describe() # Will give descriptive statistics only for numeric fields
# Out:
#                 id       season  dl_applied  win_by_runs  win_by_wickets
# count   696.000000   696.000000  696.000000   696.000000      696.000000
# mean    974.103448  2012.965517    0.027299    13.472701        3.349138
# std    2143.239623     3.069266    0.163070    23.607994        3.411398
# min       1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%     174.750000  2010.000000    0.000000     0.000000        0.000000
# 50%     348.500000  2013.000000    0.000000     0.000000        3.000000
# 75%     522.250000  2016.000000    0.000000    19.000000        6.000000
# max    7953.000000  2018.000000    1.000000   146.000000       10.000000

# %%
ipl_data.describe(include='all') # will provide stats for non numeric fields as well
# Out:
#                  id       season    city        date           team1  \
# count    696.000000   696.000000     689         696             696
# unique          NaN          NaN      32         498              14
# top             NaN          NaN  Mumbai  2011-05-05  Mumbai Indians
# freq            NaN          NaN      94           2              91
# mean     974.103448  2012.965517     NaN         NaN             NaN
# std     2143.239623     3.069266     NaN         NaN             NaN
# min        1.000000  2008.000000     NaN         NaN             NaN
# 25%      174.750000  2010.000000     NaN         NaN             NaN
# 50%      348.500000  2013.000000     NaN         NaN             NaN
# 75%      522.250000  2016.000000     NaN         NaN             NaN
# max     7953.000000  2018.000000     NaN         NaN             NaN
#
#                         team2     toss_winner toss_decision  result  \
# count                     696             696           696     696
# ...

# %%
#ipl_data.isnull().any() # check if there is any missing value
ipl_data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# From the above output we can see that <br/>
# __city__, __winner__, __player of the match__, __umpire1__, __umpire2__ , __umpire3__ columns contains maximum __null values__. We will see how to deal with them.

# %% [markdown]
# <a id=section302></a>

# %% [markdown]
#  ### 3.2 Pre Profiling

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = pandas_profiling.ProfileReport(ipl_data)
profile.to_file(output_file="ipl_before_preprocessing.html")

# %% [markdown]
# Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as __ipl_before_preprocessing.html__. <br/>
# Now we will process our data to better understand it.

# %% [markdown]
# <a id=section303></a>

# %% [markdown]
#  ### 3.3 Preprocessing

# %% [markdown]
# - Dealing with missing values<br/>
#     - Dropping the column __Umpire3__ as it has too many _null_ values.
#     - Replacing __null__ values for __umpire1__ and __umpire2__ column.
#     - Raplacing __null__ values for the __city__ column.
# - Correctnes of data<br/>
#     - Correcting Team name for __Pune's__ team.
# - New column Addition
#     - Four new columns __Batting team__, __Fielding team__, __batting winner or Bowling Winner__, __toss_winner_is_winner__ added

# %%
#ipl_data.umpire3
#ipl_data.umpire3.head() # as umpire3 have mostly values null so we will drop this column
ipl_data.drop('umpire3', axis = 1,inplace = True) # dropping umpire3 column

# %%
# Analysing missing umpire1 and umpire2
ipl_data[pd.isnull(ipl_data['umpire1'])]
ipl_data.query('season==2017 and team1=="Royal Challengers Bangalore" and team2=="Delhi Daredevils"')['umpire1'].mode()[0]
ipl_data.query('season==2017 and team1=="Royal Challengers Bangalore" and team2=="Delhi Daredevils"')['umpire2'].mode()[0]

# as per above analysis we can replace the missing value of umpire1 within group 'season','team1','team2'
ipl_data_new=ipl_data.groupby(['season','team1','team2'])['umpire1'].transform(lambda x: x.value_counts(dropna=False).index[0]).to_frame()
ipl_data.loc[ipl_data['umpire1'].isnull().to_list(),'umpire1']=ipl_data_new[ipl_data['umpire1'].isnull().to_list()]

# as per above analysis we can replace the missing value of umpire2 within group 'season','team1','team2'
ipl_data_new1=ipl_data.groupby(['season','team1','team2'])['umpire2'].transform(lambda x: x.value_counts(dropna=False).index[0]).to_frame()
ipl_data.loc[ipl_data['umpire2'].isnull().to_list(),'umpire2']=ipl_data_new1[ipl_data['umpire2'].isnull().to_list()]

# %%
# Analysing missing player of the match and winner
#ipl_data.loc[ipl_data['player_of_match'].isnull().to_list(),]
ipl_data.loc[ipl_data['winner'].isnull().to_list(),]
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2
# ...

# %% [markdown]
# <br>By Analysing above data we come to conclusion that __winner__ and __player of the match__ is null only in those cases where match could not be completed due to any reason and ended up with no result i.e. bad weather.<br>

# %%
# analysing null values for city
#ipl_data.loc[ipl_data['city'].isnull().to_list(),]# seems like all null values are for a particular season
#ipl_data.loc[ipl_data['venue']=='Dubai International Cricket Stadium'] .count()
#ipl_data.query('season==2014 & city!=city').count()
# all missing values for city are for seson 2014 so lets drill down further
ipl_data.query('season==2014')['city'].mode()[0]
# Out:
# 'Abu Dhabi'

# %% [markdown]
# As from the above analysis we can clearly say most of the matches are played out of india in __Abu Dhabi__ for season 2014.
# so lets replace all null values of city column with __'Abu Dhabi'__<br><br>

# %%
# Replacing null value with the mode of city column for season 2014
ipl_data['city'].fillna(ipl_data.query('season==2014')['city'].mode()[0], inplace = True)
#ipl_data.query('season==2014').head()

# %%
# correct the team name and make the data homogenious for column team1,team2 and winner
ipl_data['team1']=ipl_data['team1'].replace('Supergiants', 'Supergiant', regex=True)
ipl_data['team2']=ipl_data['team2'].replace('Supergiants', 'Supergiant', regex=True)
ipl_data['winner']=ipl_data['winner'].replace('Supergiants', 'Supergiant', regex=True)

# %%
# For tied matches set winner to null
ipl_data.loc[ipl_data['result'] =='tie', 'winner']= np.NaN

# %%
# introducing four new columns Batting Team,Fielding Team ,batting winner or Bowling Winner,toss_winner_is_winner
ipl_data["Batting Team"]=ipl_data.apply(lambda row: row['toss_winner'] if row['toss_decision'] == 'bat' else (row['team2'] if row['toss_winner']==row['team1'] else row['team1']), axis=1)
ipl_data["Fielding Team"]=ipl_data.apply(lambda row: row['toss_winner'] if row['toss_decision'] == 'field' else (row['team2'] if row['toss_winner']==row['team1'] else row['team1']), axis=1)
ipl_data["batting winner or Bowling Winner"]=ipl_data.apply(lambda row: 'bat' if row['winner']==row['Batting Team'] else ('field' if row['winner']==row['Fielding Team'] else 'No result or tie'),axis=1)
ipl_data['toss_winner_is_winner'] = 'no'
ipl_data['toss_winner_is_winner'].loc[ipl_data.toss_winner == ipl_data.winner] = 'yes'
# Out:
# C:\Users\SiddharthaJain\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ipl_data.to_excel("ipl_data_post_processing.xlsx",index=False)

# %% [markdown]
# <a id=section304></a>

# %% [markdown]
# ## 3.4 Post Pandas Profiling

# %%
profile = pandas_profiling.ProfileReport(ipl_data)
profile.to_file(output_file="ipl_after_preprocessing.html")
# Out:
# C:\Users\SiddharthaJain\Anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:34: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# Now we have preprocessed the data, now the dataset doesnot contain missing values except __player of the match__ and __Winner__ Column which is for the cases where match is either tied or could not complete.<br>
#
# we have also introduced new feature named __Batting_Team__, __Fielding_Team__,  __batting_winner_or_Bowling_winner__ ,__toss_winner_is_winner__.<br>
#
# So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights. We can compare the two reports, i.e __ipl_after_preprocessing.html__ and __ipl_before_preprocessing.html__.<br/>
# In ipl_after_preprocessing.html report, observations:
#
# - In the Dataset info, Total __Missing(%)__ = __.1%__
# - Number of __variables__ = __21__

# %% [markdown]
# <a id=section4></a>

# %% [markdown]
# ## 4. Questions

# %% [markdown]
# <a id=section410></a>

# %% [markdown]
# ### 4.1 Most and Least matches played ?

# %% [markdown]
# <a id=section411></a>

# %% [markdown]
#  #### 4.1.1  In which season highest and lowest number of matches played ?

# %%
df=ipl_data.groupby(['season'])['season'].count().to_frame().rename(columns={'season':'Total Matches Played'}).reset_index().rename(columns={'season':'Season'})
labels = df.Season
values = df['Total Matches Played']
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()
plt.savefig('highest and lowest number of matches played.png')
# Out:
# <div>
#
#
#             <div id="a276f715-a708-4005-b769-11b4d780559f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a276f715-a708-4005-b769-11b4d780559f")) {
#                     Plotly.newPlot(
#                         'a276f715-a708-4005-b769-11b4d780559f',
#                         [{"hole": 0.6, "labels": [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "type": "pie", "values": [58, 57, 60, 73, 74, 76, 60, 59, 60, 59, 60]}],
# ...

# %% [markdown]
# It can be seen that highest number of matches played in season 2013 followed by 2012 and than 2011.
# It might be because in these seasons number of teams participated may be higher than other seasons.
# so lets drill down further.

# %%
#Total team participated in each IPL season
df1=ipl_data[['season','team1']]
df2=ipl_data[['season','team2']]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.groupby(["season"])["team1"].nunique()
# Out:
# season
# 2008     8
# 2009     8
# 2010     8
# 2011    10
# 2012     9
# 2013     9
# 2014     8
# 2015     8
# 2016     8
# 2017     8
# 2018     8
# Name: team1, dtype: int64

# %% [markdown]
# From the above data it can be verified that top 3 seasons where maximum number of team participated are __2013__,__2012__ and __2011__.

# %% [markdown]
# <a id=section412></a>

# %% [markdown]
# #### 4.1.2 Which team played highest and lowest number of matches?

# %%
df1=ipl_data[['season','team1','winner']]
df2=ipl_data[['season','team2','winner']]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['season','team','winner']
(df['team'].value_counts()).plot.bar()

# %% [markdown]
# Above bar graph clearly shows that __Mumbai Indians__ is the team who played highest number of matches and on the contrary Kochi Tuskers Kerala have played lowest number of matches.
# For __Mumbai Indians__ It may be because it has been good performer or participated in most of the seasons as compare to other teams.<br>
# __Results for Kochi Tuskers Kerala__ could be because of less number of seasons played.
# So we have to go for further analysis.

# %% [markdown]
# <a id=section413></a>

# %% [markdown]
# #### 4.1.3 Which team played highest and lowest number of matches in each season?

# %%
df1=ipl_data[['season','team1']]
df2=ipl_data[['season','team2']]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['Season','Team']
df=pd.crosstab(df.Team,df.Season)
df
# Out:
# Season                       2008  2009  2010  2011  2012  2013  2014  2015  \
# Team
# Chennai Super Kings            16    14    16    16    18    18    16    17
# Deccan Chargers                14    16    16    14    15     0     0     0
# Delhi Daredevils               14    15    14    14    18    16    14    14
# Gujarat Lions                   0     0     0     0     0     0     0     0
# Kings XI Punjab                15    14    14    14    16    16    17    14
# Kochi Tuskers Kerala            0     0     0    14     0     0     0     0
# Kolkata Knight Riders          13    13    14    15    17    16    16    13
# Mumbai Indians                 14    13    16    16    17    19    15    16
# Pune Warriors                   0     0     0    14    16    16     0     0
# Rajasthan Royals               16    13    14    13    16    18    14    14
# Rising Pune Supergiant          0     0     0     0     0     0     0     0
# ...

# %% [markdown]
# From the above data we can easily see that only 5 teams i.e. __Delhi Daredevils__, __Kings XI Punjab__, __kolkata Knight Riders__, __Mumbai Indians__, __Royal Challengers Banglore__ have played all the seasons of IPL.<br>
# Let's plot the above data

# %%
df1=ipl_data[['id','season','team1']]
df2=ipl_data[['id','season','team2']]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['id','Season','Team']
df=df.groupby(['Season','Team']).agg(['count'])
df.reset_index(inplace=True)
df.columns=['Season','Team','Total Matches Played']
#df=df.sort_values(by=['Season','Total Matches Played'],ascending=True)
fig = px.bar(df, x="Season",y="Total Matches Played", color="Team",
                 hover_name="Team", log_x=True, title="Matches Played per season by teams",text='Total Matches Played'
            )
fig.show()
# Out:
# <div>
#
#
#             <div id="57c8833f-7d2f-4f32-998e-8236cd0f8099" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57c8833f-7d2f-4f32-998e-8236cd0f8099")) {
#                     Plotly.newPlot(
#                         '57c8833f-7d2f-4f32-998e-8236cd0f8099',
# ...

# %% [markdown]
# <a id=section414></a>

# %% [markdown]
# #### 4.1.4 What was the result of most number of the matches?

# %%
df=np.round(ipl_data['result'].value_counts().to_frame()/696*100,2)
df=df.rename(columns={'result':'Percentage'}).reset_index().rename(columns={'index':'Result'})
fig = px.bar(df, x='Result', y='Percentage',color='Result',title='Result percentage over no. of matches',text='Percentage')
fig.show()
# Out:
# <div>
#
#
#             <div id="9bcf13c4-3a12-4c64-97d4-5b5053326d9c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9bcf13c4-3a12-4c64-97d4-5b5053326d9c")) {
#                     Plotly.newPlot(
#                         '9bcf13c4-3a12-4c64-97d4-5b5053326d9c',
# ...

# %% [markdown]
# Result of most of the matches is normal i.e. approx 98.5% , 1% of the total matches got tied and only approx .5% matches ended up with no result.

# %% [markdown]
# <a id=section415></a>

# %% [markdown]
# #### 4.1.5 What was the result of most number of the matches in each season?

# %% [markdown]
# <a id=section2></a>

# %%
result_states=ipl_data.groupby(['season','result'])['id'].count().to_frame()
result_states.reset_index(inplace=True)
result_states.columns=['Season','Result','Total No. Of Matches']
result_states


fig = px.scatter(result_states, x="Season", y="Total No. Of Matches", color="Result",
	         size="Total No. Of Matches",
                 hover_name='Result', log_x=True, size_max=40,text="Total No. Of Matches",title='Total Matches Played Result wise for each Season')
fig.show()
# Out:
# <div>
#
#
#             <div id="18201d99-e44c-4971-ab06-a9486b368f4b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18201d99-e44c-4971-ab06-a9486b368f4b")) {
#                     Plotly.newPlot(
#                         '18201d99-e44c-4971-ab06-a9486b368f4b',
# ...

# %% [markdown]
# In Season __2008__, __2012__ , __2016__ ,__2018__ and __2019__ none of the matches resulted tie or ended up no result.<br>
# __Maximum__ number of __tied__ matches were in the season __2013__ which is __28%__ of the total tied IPL matches across all the season <br>
# Two matches in __2015__ ended up with __no result__ which is alomst __66%__ of the total matches ended up with no result across all the IPL seasons.

# %% [markdown]
# Note -  To know the exact count we will be using groupby

# %%
ipl_data.groupby(['season','result'])['id'].count()
# Out:
# season  result
# 2008    normal       58
# 2009    normal       56
#         tie           1
# 2010    normal       59
#         tie           1
# 2011    no result     1
#         normal       72
# 2012    normal       74
# 2013    normal       74
#         tie           2
# 2014    normal       59
#         tie           1
# 2015    no result     2
#         normal       56
#         tie           1
# 2016    normal       60
# 2017    normal       58
#         tie           1
# 2018    normal       60
# Name: id, dtype: int64

# %% [markdown]
# <a id=section420></a>

# %% [markdown]
# ### 4.2 Does venue favours any team or impact match result by batting first or fielding first?

# %% [markdown]
# <a id=section421></a>

# %% [markdown]
# #### 4.2.1 Which venue hosted higest number of matches?

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='venue', data=ipl_data,order=ipl_data['venue'].value_counts().index)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# This analysis clearly tells that __M Chinnaswamy__, __Eden Garden__ and __Feroz shah kotla__ are the TOP 3 stadium where highest number of matches played. <br>
# Lets quickly observe this result to 1 more level deeper.

# %% [markdown]
# <a id=section422></a>

# %% [markdown]
# ####  4.2.2 Win percentage at each venue by first batting or bowling?

# %%
df=ipl_data[['venue','city','winner','batting winner or Bowling Winner']]
df=df[df.winner.notnull()]
df=df[['venue','city','batting winner or Bowling Winner']]
df.columns=['Venue','City','BatOrField']
venue_total_match=df.groupby(["Venue","City"])[["City"]].count().rename(columns={"City":"MatchesPlayed"}).reset_index()
won_by_BatOrField=df.groupby(["Venue","City","BatOrField"])[["BatOrField"]].count().rename(columns={"BatOrField":"MatchesWon"}).reset_index()
df=pd.merge(venue_total_match,won_by_BatOrField,how='left',left_on=['Venue','City'],right_on=['Venue','City'])
percent_win=((df['MatchesWon']/df['MatchesPlayed'])*100).round(2).to_list()
df["PercentWin"]=percent_win
df.fillna(0,inplace = True)
df=df.query('PercentWin >= 70')
df.reset_index(inplace=True)
df[['Venue','City','BatOrField','MatchesPlayed','PercentWin']]
# Out:
#                                 Venue    City BatOrField  MatchesPlayed  \
# 0                          Green Park  Kanpur      field              4
# 1              Holkar Cricket Stadium  Indore      field              9
# 2  JSCA International Stadium Complex  Ranchi      field              7
#
#    PercentWin
# 0      100.00
# 1       88.89
# 2       71.43

# %% [markdown]
# we come to know there are three grounds __Green Park Kanpur__,__Holkar Cricket Stadium Indore__ and __JSCA International Stadium Complex Ranchi__  where if you field first your win chances are greater than 70%
# Let's plot the data for above three venues

# %%
df=ipl_data.loc[ipl_data["venue"].isin(['Green Park','Holkar Cricket Stadium','JSCA International Stadium Complex'])]
f,ax = plt.subplots(1,3,figsize=(22,6))
df['batting_winner_or_Bowling_Winner'][df['venue'] == 'Green Park'].value_counts().plot.pie(explode=[0.1],colors=('#99ff99','#ffcc99'),autopct='%1.1f%%',ax=ax[0],shadow=True)
df['batting_winner_or_Bowling_Winner'][df['venue'] == 'Holkar Cricket Stadium'].value_counts().plot.pie(explode=[0.2,0],colors=('#99ff99','#6572c9'),autopct='%1.1f%%',ax=ax[1],shadow=True)
df['batting_winner_or_Bowling_Winner'][df['venue'] == 'JSCA International Stadium Complex'].value_counts().plot.pie(explode=[0.1,0],colors=('#99ff99','#6572c9'),autopct='%1.1f%%',ax=ax[2],shadow=True)
ax[0].set_title('Green Park')
ax[1].set_title('Holkar Cricket Stadium')
ax[2].set_title('JSCA International Stadium Complex')
# Out:
# Text(0.5, 1.0, 'JSCA International Stadium Complex')

# %% [markdown]
# <a id=section423></a>

# %% [markdown]
# #### 4.2.3 Win percentage of team venue wise?

# %%
df1=ipl_data[['venue','city','team1','winner']]
df2=ipl_data[['venue','city','team2','winner']]
df2=df2[df2.winner.notnull()]
df1=df1[df1.winner.notnull()]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['Venue','City','Team','Winner']
team_total_match=df.groupby(["Venue","City","Team"])[["Team"]].count().rename(columns={"Team":"MatchesPlayed"}).reset_index()
team_total_match_won=ipl_data.groupby(["venue","city","winner"])[["winner"]].count().rename(columns={"winner":"MatchesWon"}).reset_index()
df=pd.merge(team_total_match,team_total_match_won,how='left',left_on=['Venue','City','Team'],right_on=['venue','city','winner'])
percent_win=((df['MatchesWon']/df['MatchesPlayed'])*100).round(2).to_list()
df["PercentWin"]=percent_win
df.fillna(0,inplace = True)
df=df[['Venue','City','Team','MatchesPlayed','PercentWin']].query('PercentWin >= 75 and MatchesPlayed > 5').reset_index()
df=df[['Venue','City','Team','MatchesPlayed','PercentWin']]
df
# Out:
#                                      Venue       City  \
# 0                        Brabourne Stadium     Mumbai
# 1                             Eden Gardens    Kolkata
# 2                         Feroz Shah Kotla      Delhi
# 3                    M Chinnaswamy Stadium  Bangalore
# 4  Maharashtra Cricket Association Stadium       Pune
#
#                           Team  MatchesPlayed  PercentWin
# 0               Mumbai Indians              8       75.00
# 1               Mumbai Indians             12       83.33
# 2  Royal Challengers Bangalore              8       75.00
# 3               Mumbai Indians             10       80.00
# 4          Chennai Super Kings              6       83.33

# %% [markdown]
# __Brabourne Stadium Mumbai__,__Eden Gardens Kolkata__, __M Chinnaswamy Stadium Banglore__ are the favorite grounds of the __mumbai Indians__ team, they loose only __25%__ of matches on these grounds i.e win percentage is more than equal to __75%.<br>
# similarly __Maharashtra Cricket Association Stadium Pune__ for __Chennai Super Kings__ and __Feroz Shah Kotla Delhi__ for __Royal Challengers Bangalore__ are the luckiest ground where they hardly loose any matches

# %% [markdown]
# <a id=section430></a>

# %% [markdown]
# ### 4.3 Which one is the most consistent team?

# %% [markdown]
# <a id=section431></a>

# %% [markdown]
# #### 4.3.1 What percentage of matches won by each team ?

# %%
df1=ipl_data[['season','team1','winner']]
df2=ipl_data[['season','team2','winner']]
df2=df2[df2.winner.notnull()]
df1=df1[df1.winner.notnull()]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['Season','Team','Winner']
team_total_match=df.groupby("Team")[["Team"]].count().rename(columns={"Team":"Matches Played"}).reset_index()
team_total_match_won=ipl_data.groupby("winner")[["winner"]].count().rename(columns={"winner":"Matches Won"}).reset_index()
df=pd.merge(team_total_match,team_total_match_won,how='inner',left_on='Team',right_on='winner')
percent_win=((df['Matches Won']/df['Matches Played'])*100).round(2).to_list()
df["Percent Win"]=percent_win
df=df.sort_values(['Percent Win'],ascending=False)
df[['Team','Matches Played','Matches Won','Percent Win']]

sns.set(style="whitegrid")
ax = sns.barplot(x='Percent Win', y='Team',data=df)


def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
        
show_values_on_bars(ax, "h", 0.3)

# %% [markdown]
# Top three teams wins the table are __Chennai Super Kings__, __Mumbai Indians__ and __Sunrisers Hyderabad__

# %% [markdown]
# <a id=section432></a>

# %% [markdown]
# #### 4.3.2 Win consistancy of the top teams across the seasons?

# %% [markdown]
# Note : Top teams are those, whose win percent over total matches played across all ipl seasons is greater than 50%

# %%
df1=ipl_data[['season','team1','winner']]
df2=ipl_data[['season','team2','winner']]
df2=df2[df2.winner.notnull()]
df1=df1[df1.winner.notnull()]
df2.columns = df1.columns
df=pd.concat([df1, df2],axis=0,sort=False,ignore_index=True)
df.columns=['Season','Team','Winner']
team_total_match=df.groupby("Team")[["Team"]].count().rename(columns={"Team":"Matches Played"}).reset_index()
team_total_match_won=ipl_data.groupby("winner")[["winner"]].count().rename(columns={"winner":"Matches Won"}).reset_index()
df_merge=pd.merge(team_total_match,team_total_match_won,how='inner',left_on='Team',right_on='winner')
percent_win=((df_merge['Matches Won']/df_merge['Matches Played'])*100).round(2).to_list()
df_merge["PercentWin"]=percent_win
top_teams=df_merge[['Team','PercentWin']].query("PercentWin > 50")[["Team"]]
#top_teams
# for top teams win percentage season wise
teams_total_match_season_wise=df.groupby(["Team","Season"])[["Team"]].count().rename(columns={"Team":"Matches Played"}).reset_index()
teams_total_match_won_season_wise=ipl_data.groupby(["season","winner"])[["winner"]].count().rename(columns={"winner":"Matches Won"}).reset_index()
df=pd.merge(teams_total_match_season_wise,teams_total_match_won_season_wise,how='inner',left_on=['Team','Season'],right_on=['winner','season'])
percent_win=((df['Matches Won']/df['Matches Played'])*100).round(2).to_list()
df["Percentage Win"]=percent_win
# getting  data only for top teams
df=pd.merge(df,top_teams,how='inner',left_on='Team',right_on='Team')
df=df[["Percentage Win","Team","Season"]]
fig = px.box(df, y="Percentage Win", x="Team", color="Team", points="all",title="Consistency of TOP 5 teams of IPL",hover_data=df.columns)
fig.show()
# Out:
# <div>
#
#
#             <div id="8df8a5ba-e1c7-426c-b665-998bbb6d94b6" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8df8a5ba-e1c7-426c-b665-998bbb6d94b6")) {
#                     Plotly.newPlot(
#                         '8df8a5ba-e1c7-426c-b665-998bbb6d94b6',
# ...

# %% [markdown]
# - Most consistent team is __Chennai Super king__ while most inconsistent team is __kolkata knight riders__<br>
# - __Win avg__ wise __Chennai super king__ top the table, followed by __Mumbai indians__ and then __Sunrisers Hyderabad__

# %% [markdown]
# <a id=section433></a>

# %% [markdown]
# #### 4.3.3 What is the team performance (win) season over season?

# %%
df_win=ipl_data.groupby(['season','winner']).count()['id'].to_frame()
df_win.reset_index(inplace=True)
df_win.columns=['Season','Team','Total Wins']
fig = px.line(df_win, x="Season", y="Total Wins", color='Team',title='Total team Wins over year by year')
fig.show()
# Out:
# <div>
#
#
#             <div id="5c826429-fdae-48cd-8fce-bc39e78042a0" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c826429-fdae-48cd-8fce-bc39e78042a0")) {
#                     Plotly.newPlot(
#                         '5c826429-fdae-48cd-8fce-bc39e78042a0',
# ...

# %% [markdown]
# <a id=section440></a>

# %% [markdown]
# ### 4.4 Does toss really matter?

# %% [markdown]
# <a id=section441></a>

# %%
toss_df = ipl_data[['toss_winner','winner','result']]
#toss_df.count()
toss_df.dropna(inplace=True) #Dropping any rows which contains null values
#toss_df.count()
# Out:
# C:\Users\SiddharthaJain\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Count of the matches where toss winner won the match
toss_df[toss_df.winner == toss_df.toss_winner].count()
# Out:
# toss_winner    351
# winner         351
# result         351
# dtype: int64

# %%
toss_df[toss_df.winner != toss_df.toss_winner].count()
# Out:
# toss_winner    335
# winner         335
# result         335
# dtype: int64

# %%
colors = ['gold', 'darkorange']

labels = ['Yes','No']
values = [351/(335+351),335/(335+351)]

fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.5,title='Toss winner is match winner?')])
fig.show()
# Out:
# <div>
#
#
#             <div id="1305a4a5-d6d0-475f-bf8c-da5c30265cfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1305a4a5-d6d0-475f-bf8c-da5c30265cfa")) {
#                     Plotly.newPlot(
#                         '1305a4a5-d6d0-475f-bf8c-da5c30265cfa',
#                         [{"hole": 0.5, "labels": ["Yes", "No"], "title": {"text": "Toss winner is match winner?"}, "type": "pie", "values": [0.5116618075801749, 0.48833819241982507]}],
# ...

# %% [markdown]
# It is not really the case it seems. The chance is almost 50-50 for both the teams.
# Let us also look at the team wise break up. If the team wins the toss, will it end up in the winning side. Will be interesting to see.

# %%
df=ipl_data
df.dropna(inplace=True) #Dropping any rows which contains null values
df.toss_winner_is_winner.value_counts()
plt.figure(figsize=(12,6))
sns.countplot(x='toss_winner', hue='toss_winner_is_winner', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# It seems for Chennai Super Kings (CSK) winning the toss is an indication of winning the match with high probability.
# On the other hand, Pune Warriors end up losing the matches more often when they won the toss.

# %% [markdown]
# <a id=section450></a>

# %% [markdown]
# ### 4.5 What happened in the final matches of the seasons ?

# %% [markdown]
# <a id=section451></a>

# %% [markdown]
# #### 4.5.1 Which two teams reached to the finals of each season,who is the winner and man of the match?

# %%
team_batteling_finals=ipl_data.groupby('season')['date'].max().to_frame() 
team_batteling_finals.reset_index(inplace=True)
df=pd.merge(team_batteling_finals,ipl_data[['date','team1','team2','winner','player_of_match']],how='inner',on='date')[['season','date','team1','team2','winner','player_of_match']]
df
# Out:
#     season        date                team1                        team2  \
# 0     2008  2008-06-01  Chennai Super Kings             Rajasthan Royals
# 1     2009  2009-05-24      Deccan Chargers  Royal Challengers Bangalore
# 2     2010  2010-04-25  Chennai Super Kings               Mumbai Indians
# 3     2011  2011-05-28  Chennai Super Kings  Royal Challengers Bangalore
# 4     2012  2012-05-27  Chennai Super Kings        Kolkata Knight Riders
# 5     2013  2013-05-26       Mumbai Indians          Chennai Super Kings
# 6     2014  2014-06-01      Kings XI Punjab        Kolkata Knight Riders
# 7     2015  2015-05-24       Mumbai Indians          Chennai Super Kings
# 8     2016  2016-05-29  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9     2017  2017-05-21       Mumbai Indians       Rising Pune Supergiant
# 10    2018    30/04/18  Chennai Super Kings             Delhi Daredevils
#
#                    winner player_of_match
# 0        Rajasthan Royals       YK Pathan
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id=section452></a>

# %% [markdown]
# #### 4.5.2 Which team reached to the finals maximum number of times?

# %%
df1=pd.merge(team_batteling_finals,ipl_data[['date','team1','team2']],how='inner',on='date')[['date','team1','team2']]
df2=df1[['date','team1','team2']]
df2.columns=['date','team2','team1']
df=pd.concat([df1[['date','team1']], df2[['date','team1']]],axis=0,sort=False,ignore_index=True)
final_qualify=df.team1.value_counts()
final_qualify
# Out:
# Chennai Super Kings            7
# Mumbai Indians                 4
# Royal Challengers Bangalore    3
# Kolkata Knight Riders          2
# Deccan Chargers                1
# Rising Pune Supergiant         1
# Rajasthan Royals               1
# Sunrisers Hyderabad            1
# Kings XI Punjab                1
# Delhi Daredevils               1
# Name: team1, dtype: int64

# %% [markdown]
# __Chennai Super King__ Qualified for maximum number of times to the finals,followed by __Mumbai Indians__ and __Royal Challengers Banglore__

# %% [markdown]
# <a id=section453></a>

# %% [markdown]
# #### 4.5.3 Which team won the IPL final Maximum number of times?

# %%
df1=pd.merge(team_batteling_finals,ipl_data[['date','season','winner']],how='inner',on=['date','season'])
#df=df.groupby('winner')['winner'].count()
final_win=df1.winner.value_counts()
final_win
# Out:
# Chennai Super Kings      3
# Mumbai Indians           3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Name: winner, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id=section454></a>

# %% [markdown]
# Here is a tie between __chennai super king__ and __Mumbai Indians__

# %% [markdown]
# #### 4.5.4 What are the chances for a final's qualifier to win the finals ?

# %%
df1=pd.merge(team_batteling_finals,ipl_data[['date','team1','team2']],how='inner',on='date')[['date','team1','team2']]
df2=df1[['date','team1','team2']]
df2.columns=['date','team2','team1']
df=pd.concat([df1[['date','team1']], df2[['date','team1']]],axis=0,sort=False,ignore_index=True)
final_qualify=df.team1.value_counts()
final_qualify=final_qualify.to_frame()
final_qualify.reset_index(inplace=True)
final_qualify.columns=['Team','QualifyTimes']
df1=pd.merge(team_batteling_finals,ipl_data[['date','season','winner']],how='inner',on=['date','season'])
final_win=df1.winner.value_counts()
final_win=final_win.to_frame()
final_win.reset_index(inplace=True)
final_win.columns=['Team','WinTimes']
df=pd.merge(final_qualify,final_win,how='left',left_on='Team',right_on='Team')
df['Chances']=np.round((df['WinTimes']/df['QualifyTimes'])*100,2)
df.fillna(0,inplace=True)
df.loc[df['QualifyTimes'] >=2].sort_values(['Chances'],ascending=False)
# Out:
#                           Team  QualifyTimes  WinTimes  Chances
# 3        Kolkata Knight Riders             2       2.0   100.00
# 1               Mumbai Indians             4       3.0    75.00
# 0          Chennai Super Kings             7       3.0    42.86
# 2  Royal Challengers Bangalore             3       0.0     0.00

# %% [markdown]
# Based on the above observation we can say that chances of winning the IPL for __Mumbai Indians__ and __Kolkata Knight Riders__ are quiet high when they qualify for the finals.

# %% [markdown]
# <a id=section460></a>

# %% [markdown]
# ### 4.6 Other Analysis

# %% [markdown]
# <a id=section461></a>

# %% [markdown]
# #### 4.6.1 What percentages of matche's result  decided by Duckworth Lewis method?

# %%
#ipl_data[ipl_data['dl_applied'] == 1].count() # 19 matches
dl_used =ipl_data.loc[ipl_data['dl_applied'] == 1][['season','team1','team2']]

np.round((dl_used['season'].count()/ipl_data[ipl_data.winner.notnull()]['id'].count())*100,2)
# Out:
# 2.77

# %% [markdown]
# From the above observation we come to know that result of __19__ matches were decided by __DL__ method which is only __2%-3%__ of the matches played across IPL seasons.

# %% [markdown]
# ## 5. Conclusion
#
# #### We can easily conclude below points from above graphs <br>
# - Highest number of matches played in season 2013 followed by 2012 and then 2011.
# - __Mumbai Indians__ is the team who played highest number of matches and on the contrary __Kochi Tuskers Kerala__ have played lowest number of matches across all seasons of IPL.
# - Only 5 teams i.e. __Delhi Daredevils, Kings XI Punjab, Kolkata Knight Riders, Mumbai Indians, Royal Challengers Banglore__ have played all the seasons of IPL.
# - Across all sesons of IPL, results of most of the matches are normal i.e. approx __98.5%__, __1%__ of the total matches got tied and only approx __.5%__ matches ended up with no result.
# - In Seasons __2008, 2012, 2016, 2018 and 2019__ none of the matches resulted Tie or ended up no result.
#   Maximum number of tied matches were in the season __2013__ which is 28% of the total tied IPL matches across all the seasons
#   Two matches in __2015__ ended up with no result which is alomst 66% of the total matches ended up with no result across all the IPL seasons.
# - __M Chinnaswamy, Eden Garden and Feroz Shah Kotla__ are the TOP 3 stadium where highest number of matches played.
# - Three grounds __Green Park Kanpur, Holkar Cricket Stadium Indore and JSCA International Stadium Complex Ranchi__, where if you field first your chances of winning the match are greater than 70%
# - __Brabourne Stadium, Eden Gardens, M Chinnaswamy Stadium__ are the favorite ground of the __Mumbai Indians__ team. They loosed only 25% of matches on these ground, similarly __Maharashtra Cricket Association Stadium Pune__ for __Chennai Super Kings__ and __Feroz Shah Kotla__ for __Royal Challengers Bangalore__ are the luckiest ground where they hardly loose matches.
# - Top three teams who wins the table of win percentage across all IPL seasons are __Chennai Super Kings, Mumbai Indians and Sunrisers Hyderabad__.
# - Most consistent team is __Chennai Super King__ while most inconsistent team is __Kolkata Knight Riders__.
# - It seems for __Chennai Super Kings (CSK)__ winning the toss is an indication of winning the match with high probability. On the other hand, __Pune Warriors__ end up losing the matches more often when they won the toss.
# - __Chennai Super King__ Qualified for maximum number of times to the finals, followed by __Mumbai Indians and Royal Challengers Banglore__.
# - __Chennai Super King and Mumbai Indians__ won the IPL title equal number of times.
# - We can say as compare to other teams that chances of winning the IPL for __Mumbai Indians and Kolkata Knight Riders__ are quiet high when they qualify for the finals.
